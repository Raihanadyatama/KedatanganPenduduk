# %%
import pandas as pd
import os
import numpy as np
import calendar
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
all_months_data = pd.DataFrame()
files = [file for file in os.listdir('./DataKedatangan')]
for file in files:
    df = pd.read_csv('./DataKedatangan/'+file)
    all_months_data = pd.concat([all_months_data, df])

# %%
all_months_data.to_csv('all_data.csv', index = False)

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head(50)
# Out:
#     tahun  bulan         kota_kabupaten                 kecamatan  \
# 0    2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1    2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2    2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3    2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4    2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 5    2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 6    2020      8          JAKARTA PUSAT                    GAMBIR
# 7    2020      8          JAKARTA PUSAT                    GAMBIR
# 8    2020      8          JAKARTA PUSAT                    GAMBIR
# 9    2020      8          JAKARTA PUSAT                    GAMBIR
# 10   2020      8          JAKARTA PUSAT                    GAMBIR
# 11   2020      8          JAKARTA PUSAT                    GAMBIR
# 12   2020      8          JAKARTA PUSAT               SAWAH BESAR
# 13   2020      8          JAKARTA PUSAT               SAWAH BESAR
# 14   2020      8          JAKARTA PUSAT               SAWAH BESAR
# 15   2020      8          JAKARTA PUSAT               SAWAH BESAR
# 16   2020      8          JAKARTA PUSAT               SAWAH BESAR
# 17   2020      8          JAKARTA PUSAT                 KEMAYORAN
# 18   2020      8          JAKARTA PUSAT                 KEMAYORAN
# 19   2020      8          JAKARTA PUSAT                 KEMAYORAN
# 20   2020      8          JAKARTA PUSAT                 KEMAYORAN
# 21   2020      8          JAKARTA PUSAT                 KEMAYORAN
# 22   2020      8          JAKARTA PUSAT                 KEMAYORAN
# 23   2020      8          JAKARTA PUSAT                 KEMAYORAN
# 24   2020      8          JAKARTA PUSAT                 KEMAYORAN
# 25   2020      8          JAKARTA PUSAT                 S E N E N
# 26   2020      8          JAKARTA PUSAT                 S E N E N
# 27   2020      8          JAKARTA PUSAT                 S E N E N
# 28   2020      8          JAKARTA PUSAT                 S E N E N
# 29   2020      8          JAKARTA PUSAT                 S E N E N
# 30   2020      8          JAKARTA PUSAT                 S E N E N
# 31   2020      8          JAKARTA PUSAT             CEMPAKA PUTIH
# 32   2020      8          JAKARTA PUSAT             CEMPAKA PUTIH
# 33   2020      8          JAKARTA PUSAT             CEMPAKA PUTIH
# 34   2020      8          JAKARTA PUSAT                   MENTENG
# 35   2020      8          JAKARTA PUSAT                   MENTENG
# 36   2020      8          JAKARTA PUSAT                   MENTENG
# 37   2020      8          JAKARTA PUSAT                   MENTENG
# 38   2020      8          JAKARTA PUSAT                   MENTENG
# 39   2020      8          JAKARTA PUSAT               TANAH ABANG
# 40   2020      8          JAKARTA PUSAT               TANAH ABANG
# 41   2020      8          JAKARTA PUSAT               TANAH ABANG
# 42   2020      8          JAKARTA PUSAT               TANAH ABANG
# 43   2020      8          JAKARTA PUSAT               TANAH ABANG
# 44   2020      8          JAKARTA PUSAT               TANAH ABANG
# 45   2020      8          JAKARTA PUSAT               TANAH ABANG
# 46   2020      8          JAKARTA PUSAT                JOHAR BARU
# 47   2020      8          JAKARTA PUSAT                JOHAR BARU
# 48   2020      8          JAKARTA PUSAT                JOHAR BARU
# 49   2020      8          JAKARTA PUSAT                JOHAR BARU
#
#                 kelurahan jenis_kelamin   jumlah   9
# 0          PULAU PANGGANG      Laki-Laki     5.0 NaN
# 1            PULAU KELAPA      Laki-Laki     6.0 NaN
# 2           PULAU HARAPAN      Laki-Laki     1.0 NaN
# 3       PULAU UNTUNG JAWA      Laki-Laki     3.0 NaN
# 4            PULAU TIDUNG      Laki-Laki     8.0 NaN
# 5              PULAU PARI      Laki-Laki     6.0 NaN
# 6                  GAMBIR      Laki-Laki     1.0 NaN
# 7                  CIDENG      Laki-Laki     0.0 NaN
# 8            PETOJO UTARA      Laki-Laki     9.0 NaN
# 9          PETOJO SELATAN      Laki-Laki    12.0 NaN
# 10           KEBON KELAPA      Laki-Laki     4.0 NaN
# 11              DURI PULO      Laki-Laki    12.0 NaN
# 12             PASAR BARU      Laki-Laki     8.0 NaN
# 13           KARANG ANYAR      Laki-Laki    14.0 NaN
# 14                KARTINI      Laki-Laki     3.0 NaN
# 15    GUNUNG SAHARI UTARA      Laki-Laki     1.0 NaN
# 16     MANGGA DUA SELATAN      Laki-Laki    10.0 NaN
# 17              KEMAYORAN      Laki-Laki    16.0 NaN
# 18           KEBON KOSONG      Laki-Laki    22.0 NaN
# 19          HARAPAN MULIA      Laki-Laki    15.0 NaN
# 20                SERDANG      Laki-Laki    17.0 NaN
# 21  GUNUNG SAHARI SELATAN      Laki-Laki     4.0 NaN
# 22           CEMPAKA BARU      Laki-Laki    12.0 NaN
# 23             SUMUR BATU      Laki-Laki    11.0 NaN
# 24           UTAN PANJANG      Laki-Laki    17.0 NaN
# 25                  SENEN      Laki-Laki     5.0 NaN
# 26                 KENARI      Laki-Laki     9.0 NaN
# 27                PASEBAN      Laki-Laki    17.0 NaN
# 28                 KRAMAT      Laki-Laki    21.0 NaN
# 29                KWITANG      Laki-Laki    10.0 NaN
# 30                 BUNGUR      Laki-Laki    11.0 NaN
# 31    CEMPAKA PUTIH TIMUR      Laki-Laki     9.0 NaN
# 32    CEMPAKA PUTIH BARAT      Laki-Laki    18.0 NaN
# 33               RAWASARI      Laki-Laki    12.0 NaN
# 34                MENTENG      Laki-Laki    12.0 NaN
# 35             PEGANGSAAN      Laki-Laki     4.0 NaN
# 36                 CIKINI      Laki-Laki     2.0 NaN
# 37             GONDANGDIA      Laki-Laki     1.0 NaN
# 38            KEBON SIRIH      Laki-Laki    11.0 NaN
# 39                 GELORA      Laki-Laki     0.0 NaN
# 40        BENDUNGAN HILIR      Laki-Laki    11.0 NaN
# 41          KARET TENGSIN      Laki-Laki     8.0 NaN
# 42             PETAMBURAN      Laki-Laki    21.0 NaN
# 43           KEBON MELATI      Laki-Laki    14.0 NaN
# 44           KEBON KACANG      Laki-Laki     9.0 NaN
# 45           KAMPUNG BALI      Laki-Laki     3.0 NaN
# 46             JOHAR BARU      Laki-Laki    13.0 NaN
# 47           KAMPUNG RAWA      Laki-Laki    10.0 NaN
# 48                  GALUR      Laki-Laki     7.0 NaN
# 49           TANAH TINGGI      Laki-Laki    19.0 NaN

# %%
all_data = all_data.drop(['9'], axis = 1)

# %%
all_data.head()
# Out:
#    tahun  bulan         kota_kabupaten                 kecamatan  \
# 0   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3   2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4   2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            kelurahan jenis_kelamin   jumlah
# 0     PULAU PANGGANG      Laki-Laki     5.0
# 1       PULAU KELAPA      Laki-Laki     6.0
# 2      PULAU HARAPAN      Laki-Laki     1.0
# 3  PULAU UNTUNG JAWA      Laki-Laki     3.0
# 4       PULAU TIDUNG      Laki-Laki     8.0

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tahun           6408 non-null   int64
#  1   bulan           6408 non-null   int64
#  2   kota_kabupaten  6408 non-null   object
#  3   kecamatan       6408 non-null   object
#  4   kelurahan       6408 non-null   object
#  5   jenis_kelamin   6408 non-null   object
#  6   jumlah          6299 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 350.6+ KB

# %%
nan_data = all_data[all_data.isna().any(axis=1)]
nan_data
# Out:
#       tahun  bulan         kota_kabupaten                 kecamatan  \
# 539    2020      4  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 542    2020      4          JAKARTA PUSAT                    GAMBIR
# 555    2020      4          JAKARTA PUSAT                 KEMAYORAN
# 559    2020      4          JAKARTA PUSAT                 S E N E N
# 563    2020      4          JAKARTA PUSAT                 S E N E N
# 581    2020      4          JAKARTA PUSAT                JOHAR BARU
# 591    2020      4          JAKARTA UTARA             TANJUNG PRIOK
# 618    2020      4          JAKARTA BARAT                CENGKARENG
# 621    2020      4          JAKARTA BARAT         GROGOL PETAMBURAN
# 629    2020      4          JAKARTA BARAT                TAMAN SARI
# 632    2020      4          JAKARTA BARAT                TAMAN SARI
# 634    2020      4          JAKARTA BARAT                TAMAN SARI
# 636    2020      4          JAKARTA BARAT                   TAMBORA
# 641    2020      4          JAKARTA BARAT                   TAMBORA
# 643    2020      4          JAKARTA BARAT                   TAMBORA
# 645    2020      4          JAKARTA BARAT                   TAMBORA
# 646    2020      4          JAKARTA BARAT                   TAMBORA
# 664    2020      4          JAKARTA BARAT                 PAL MERAH
# 677    2020      4        JAKARTA SELATAN                     TEBET
# 678    2020      4        JAKARTA SELATAN                SETIA BUDI
# 679    2020      4        JAKARTA SELATAN                SETIA BUDI
# 709    2020      4        JAKARTA SELATAN            KEBAYORAN BARU
# 710    2020      4        JAKARTA SELATAN            KEBAYORAN BARU
# 711    2020      4        JAKARTA SELATAN            KEBAYORAN BARU
# 712    2020      4        JAKARTA SELATAN            KEBAYORAN BARU
# 713    2020      4        JAKARTA SELATAN            KEBAYORAN BARU
# 715    2020      4        JAKARTA SELATAN            KEBAYORAN BARU
# 737    2020      4          JAKARTA TIMUR                  MATRAMAN
# 738    2020      4          JAKARTA TIMUR                  MATRAMAN
# 797    2020      4          JAKARTA TIMUR                  CIPAYUNG
# 806    2020      4  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 809    2020      4          JAKARTA PUSAT                    GAMBIR
# 822    2020      4          JAKARTA PUSAT                 KEMAYORAN
# 826    2020      4          JAKARTA PUSAT                 S E N E N
# 830    2020      4          JAKARTA PUSAT                 S E N E N
# 848    2020      4          JAKARTA PUSAT                JOHAR BARU
# 858    2020      4          JAKARTA UTARA             TANJUNG PRIOK
# 885    2020      4          JAKARTA BARAT                CENGKARENG
# 888    2020      4          JAKARTA BARAT         GROGOL PETAMBURAN
# 896    2020      4          JAKARTA BARAT                TAMAN SARI
# 899    2020      4          JAKARTA BARAT                TAMAN SARI
# 901    2020      4          JAKARTA BARAT                TAMAN SARI
# 903    2020      4          JAKARTA BARAT                   TAMBORA
# 908    2020      4          JAKARTA BARAT                   TAMBORA
# 910    2020      4          JAKARTA BARAT                   TAMBORA
# 912    2020      4          JAKARTA BARAT                   TAMBORA
# 913    2020      4          JAKARTA BARAT                   TAMBORA
# 931    2020      4          JAKARTA BARAT                 PAL MERAH
# 944    2020      4        JAKARTA SELATAN                     TEBET
# 945    2020      4        JAKARTA SELATAN                SETIA BUDI
# 946    2020      4        JAKARTA SELATAN                SETIA BUDI
# 976    2020      4        JAKARTA SELATAN            KEBAYORAN BARU
#
# 1700           MANGGA BESAR      Laki-Laki     NaN
# 1752                 GUNTUR      Laki-Laki     NaN
# 1967           MANGGA BESAR      Perempuan     NaN
# 2019                 GUNTUR      Perempuan     NaN
# 2326                 CIKOKO      Laki-Laki     NaN
# 2406      PULAU UNTUNG JAWA      Perempuan     NaN
# 2514             ROA MALAKA      Perempuan     NaN
# 2672          PULAU HARAPAN      Laki-Laki     NaN
# 2781             ROA MALAKA      Laki-Laki     NaN
# 2939          PULAU HARAPAN      Perempuan     NaN
# 3048             ROA MALAKA      Perempuan     NaN
# 3883         KARET SEMANGGI      Laki-Laki     NaN
# 3917             RAWA BARAT      Laki-Laki     NaN
# 4150         KARET SEMANGGI      Perempuan     NaN
# 4184             RAWA BARAT      Perempuan     NaN
# 4272         PULAU PANGGANG      Laki-Laki     NaN
# 4273           PULAU KELAPA      Laki-Laki     NaN
# 4277             PULAU PARI      Laki-Laki     NaN
# 4279                 CIDENG      Laki-Laki     NaN
# 4309             GONDANGDIA      Laki-Laki     NaN
# 4311                 GELORA      Laki-Laki     NaN
# 4367                 KRUKUT      Laki-Laki     NaN
# 4371              KEAGUNGAN      Laki-Laki     NaN
# 4372                 GLODOK      Laki-Laki     NaN
# 4373              PINANGSIA      Laki-Laki     NaN
# 4374                TAMBORA      Laki-Laki     NaN
# 4383             ROA MALAKA      Laki-Laki     NaN
# 4416             SETIA BUDI      Laki-Laki     NaN
# 4423         KUNINGAN TIMUR      Laki-Laki     NaN
# 4432                RAGUNAN      Laki-Laki     NaN
# 4453                   PULO      Laki-Laki     NaN
# 4462                 CIKOKO      Laki-Laki     NaN
# 4539         PULAU PANGGANG      Perempuan     NaN
# 4540           PULAU KELAPA      Perempuan     NaN
# 4544             PULAU PARI      Perempuan     NaN
# 4546                 CIDENG      Perempuan     NaN
# 4576             GONDANGDIA      Perempuan     NaN
# 4578                 GELORA      Perempuan     NaN
# 4634                 KRUKUT      Perempuan     NaN
# 4638              KEAGUNGAN      Perempuan     NaN
# 4639                 GLODOK      Perempuan     NaN
# 4640              PINANGSIA      Perempuan     NaN
# 4641                TAMBORA      Perempuan     NaN
# 4650             ROA MALAKA      Perempuan     NaN
# 4683             SETIA BUDI      Perempuan     NaN
# 4690         KUNINGAN TIMUR      Perempuan     NaN
# 4699                RAGUNAN      Perempuan     NaN
# 4720                   PULO      Perempuan     NaN
# 4729                 CIKOKO      Perempuan     NaN

# %%
all_data = all_data.dropna()
all_data.head()
# Out:
#    tahun  bulan         kota_kabupaten                 kecamatan  \
# 0   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3   2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4   2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            kelurahan jenis_kelamin   jumlah
# 0     PULAU PANGGANG      Laki-Laki     5.0
# 1       PULAU KELAPA      Laki-Laki     6.0
# 2      PULAU HARAPAN      Laki-Laki     1.0
# 3  PULAU UNTUNG JAWA      Laki-Laki     3.0
# 4       PULAU TIDUNG      Laki-Laki     8.0

# %%
temp_df = all_data[all_data['jumlah'] == 0.0]
temp_df.head()
# Out:
#      tahun  bulan   kota_kabupaten       kecamatan   kelurahan jenis_kelamin   \
# 7     2020      8    JAKARTA PUSAT          GAMBIR      CIDENG      Laki-Laki
# 39    2020      8    JAKARTA PUSAT     TANAH ABANG      GELORA      Laki-Laki
# 100   2020      8    JAKARTA BARAT      TAMAN SARI      GLODOK      Laki-Laki
# 144   2020      8  JAKARTA SELATAN      SETIA BUDI  SETIA BUDI      Laki-Laki
# 180   2020      8  JAKARTA SELATAN  KEBAYORAN BARU     SENAYAN      Laki-Laki
#
#      jumlah
# 7       0.0
# 39      0.0
# 100     0.0
# 144     0.0
# 180     0.0

# %%
all_data = all_data[all_data['jumlah']!= 0.0]
all_data.head()
# Out:
#    tahun  bulan         kota_kabupaten                 kecamatan  \
# 0   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3   2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4   2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            kelurahan jenis_kelamin   jumlah
# 0     PULAU PANGGANG      Laki-Laki     5.0
# 1       PULAU KELAPA      Laki-Laki     6.0
# 2      PULAU HARAPAN      Laki-Laki     1.0
# 3  PULAU UNTUNG JAWA      Laki-Laki     3.0
# 4       PULAU TIDUNG      Laki-Laki     8.0

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6143 entries, 0 to 6407
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tahun           6143 non-null   int64
#  1   bulan           6143 non-null   int64
#  2   kota_kabupaten  6143 non-null   object
#  3   kecamatan       6143 non-null   object
#  4   kelurahan       6143 non-null   object
#  5   jenis_kelamin   6143 non-null   object
#  6   jumlah          6143 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 383.9+ KB

# %%
rename_columns = ['Tahun', 'Bulan', 'Kota_Kabupaten', 'Kecamatan','Kelurahan','Jenis_Kelamin','Jumlah']

# %%
all_data.columns = rename_columns
all_data.head()
# Out:
#    Tahun  Bulan         Kota_Kabupaten                 Kecamatan  \
# 0   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2   2020      8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3   2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4   2020      8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            Kelurahan Jenis_Kelamin  Jumlah
# 0     PULAU PANGGANG     Laki-Laki     5.0
# 1       PULAU KELAPA     Laki-Laki     6.0
# 2      PULAU HARAPAN     Laki-Laki     1.0
# 3  PULAU UNTUNG JAWA     Laki-Laki     3.0
# 4       PULAU TIDUNG     Laki-Laki     8.0

# %%
all_data['Tahun'] = pd.Categorical(all_data.Tahun)
all_data['Bulan'] = pd.Categorical(all_data.Bulan)
all_data['Kota_Kabupaten'] = pd.Categorical(all_data.Kota_Kabupaten)
all_data['Kecamatan'] = pd.Categorical(all_data.Kecamatan)
all_data['Jenis_Kelamin'] = pd.Categorical(all_data.Jenis_Kelamin)
all_data['Jumlah'] = all_data['Jumlah'].astype('int')
all_data.head()
# Out:
#   Tahun Bulan         Kota_Kabupaten                 Kecamatan  \
# 0  2020     8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1  2020     8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2  2020     8  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3  2020     8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4  2020     8  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            Kelurahan Jenis_Kelamin  Jumlah
# 0     PULAU PANGGANG     Laki-Laki       5
# 1       PULAU KELAPA     Laki-Laki       6
# 2      PULAU HARAPAN     Laki-Laki       1
# 3  PULAU UNTUNG JAWA     Laki-Laki       3
# 4       PULAU TIDUNG     Laki-Laki       8

# %%
all_data['Bulan'] = all_data['Bulan'].apply(lambda x: calendar.month_abbr[x])

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6143 entries, 0 to 6407
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Tahun           6143 non-null   category
#  1   Bulan           6143 non-null   category
#  2   Kota_Kabupaten  6143 non-null   category
#  3   Kecamatan       6143 non-null   category
#  4   Kelurahan       6143 non-null   object
#  5   Jenis_Kelamin   6143 non-null   category
#  6   Jumlah          6143 non-null   int32
# dtypes: category(5), int32(1), object(1)
# memory usage: 152.4+ KB

# %%
all_data['Jumlah'].sum()
# Out:
# 113814

# %%
result = all_data.groupby('Bulan').sum()
result
# Out:
#        Jumlah
# Bulan
# Jan     13360
# Feb     11888
# Mar      7421
# Apr      2288
# May      3248
# Jun     10363
# Jul     13376
# Aug     11000
# Sep     10990
# Oct      8849
# Nov     11029
# Dec     10002

# %%
result.plot(kind='bar',color='green')
plt.show()

# %%
result1 = all_data.groupby('Kota_Kabupaten').sum()
result1
# Out:
#                        Jumlah
# Kota_Kabupaten
# ADM. KEPULAUAN SERIBU     372
# JAKARTA BARAT           25360
# JAKARTA PUSAT           10152
# JAKARTA SELATAN         22126
# JAKARTA TIMUR           37548
# JAKARTA UTARA           18256

# %%
result1.plot(kind='bar')
plt.show()

# %%
result2 = all_data.groupby('Jenis_Kelamin').sum()
result2
# Out:
#                Jumlah
# Jenis_Kelamin
# Laki-Laki       54443
# Perempuan       59371

# %%
result2.plot(kind='pie', y='Jumlah',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Jumlah'>

# %%
result3= all_data.groupby('Bulan').mean()
result3
# Out:
#           Jumlah
# Bulan
# Jan    25.160075
# Feb    22.817658
# Mar    14.409709
# Apr     5.247706
# May     6.866808
# Jun    20.044487
# Jul    25.478095
# Aug    20.793951
# Sep    21.013384
# Oct    17.017308
# Nov    20.927894
# Dec    19.015209

# %%
result3.plot(kind='line')
plt.grid()
plt.show()

# %%
all_data.head()
# Out:
#   Tahun Bulan         Kota_Kabupaten                 Kecamatan  \
# 0  2020   Aug  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1  2020   Aug  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2  2020   Aug  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3  2020   Aug  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4  2020   Aug  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            Kelurahan Jenis_Kelamin  Jumlah
# 0     PULAU PANGGANG     Laki-Laki       5
# 1       PULAU KELAPA     Laki-Laki       6
# 2      PULAU HARAPAN     Laki-Laki       1
# 3  PULAU UNTUNG JAWA     Laki-Laki       3
# 4       PULAU TIDUNG     Laki-Laki       8

# %%
perbandingan=pd.pivot_table(all_data, index=['Bulan'], columns=['Jenis_Kelamin'], values=['Jumlah'], aggfunc='sum')
perbandingan
# Out:
#                  Jumlah
# Jenis_Kelamin Laki-Laki Perempuan
# Bulan
# Jan                6440      6920
# Feb                5663      6225
# Mar                3537      3884
# Apr                1111      1177
# May                1562      1686
# Jun                4969      5394
# Jul                6423      6953
# Aug                5280      5720
# Sep                5196      5794
# Oct                4186      4663
# Nov                5257      5772
# Dec                4819      5183

# %%
plt.figure()
perbandingan.plot.bar(title='Jumlah Laki-laki dan Perempuan tiap Bulannya')
plt.xlabel('Bulan')
plt.ylabel('Jumlah') 
plt.show()
